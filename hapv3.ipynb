# %%
import pandas as pd # bibliote Pandas é usada para manipulação de dados
import matplotlib.pyplot as plt # biblioteca para visualização dos dados

# CSV file
data = pd.read_excel("C:\\Users\\eduar\\Downloads\\hapvida.xlsx", header=(0))
print("Número de linhas e colunas:",data.shape)
data.head(25)
# Out:
# Número de linhas e colunas: (59, 8)
#        Série  Preço  Coberto     Trava  Descoberto     Total  Titular  \
# 0    HAPVC12  12.00     1000     51400           0     52400       26
# 1   HAPVC140  14.00   346100         0         300    346400        2
# 2    HAPVC15  15.00   346100      3300         100    349500        6
# 3   HAPVC420   4.20        0      5800       11000     16800        2
# 4   HAPVC440   4.40        0     20900           0     20900        3
# 5   HAPVC450   4.50    11000    157400      270400    438800        9
# 6   HAPVC460   4.60      300     45600       29600     75500        3
# 7   HAPVC470   4.70        0    130100        5000    135100        7
# 8   HAPVC480   4.80     6700    142200        3300    152200        6
# 9   HAPVC490   4.90    12100    813300      298900   1124300       12
# 10  HAPVC500   5.00    43700    363600      663300   1070600       19
# 11  HAPVC510   5.10    72200    123600      804200   1000000        2
# ...

# %%
print(data.dtypes)
# Out:
# Série          object
# Preço         float64
# Coberto         int64
# Trava           int64
# Descoberto      int64
# Total           int64
# Titular         int64
# Lançador        int64
# dtype: object

# %%
vetor_serie = data['Série'].values
vetor_Preço = data['Preço'].values
vetor_coberto = data['Coberto'].values/1000
vetor_trava = data['Trava'].values/1000
vetor_descoberto = data['Descoberto'].values/1000
plt.scatter( data['Preço'],data['Descoberto'],color = "r", s = 5 )
y = vetor_preco = data['Preço'].values
x = vetor_trava = data['Trava'].values

y2 = vetor_preco = data['Preço'].values
x2 = vetor_coberto = data['Coberto'].values
plt.scatter( x2, y2, color = "r", s = 5 )
plt.ylabel('Trava', fontsize = 15)
plt.ylabel('Descoberto', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
plt.bar( data['Preço'],data['Descoberto'])
plt.ylabel('Trava', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
y2 = vetor_preco = data['Preço'].values
x2 = vetor_coberto = data['Coberto'].values
plt.scatter( x2, y2, color = "r", s = 5 )

plt.show()



plt.barh( data['Preço'].values,data['Descoberto'].values)
plt.ylabel('Descoberto', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
plt.plot( data['Preço'].values,data['Descoberto'].values)
plt.ylabel('Descoberto', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
plt.plot( data['Preço'],data['Trava'])
plt.ylabel('Trava', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
plt.scatter( data['Preço'],data['Trava'], color = "r", s = 5)
plt.ylabel('Trava', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
plt.bar( data['Preço'],data['Trava'], color = "r")
plt.ylabel('Trava', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
plt.barh( data['Preço'],data['Trava'], color = "r")
plt.ylabel('Trava', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()
plt.barh( data['Preço'],data['Descoberto'])
plt.ylabel('Descoberto', fontsize = 15)
plt.xlabel('Preço', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Criar figura e eixo 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Configurar título e rótulos dos eixos
ax.set_title('Ambiente de Plotagem 3D', fontsize=18)
ax.set_xlabel('Eixo X', fontsize=15)
ax.set_ylabel('Eixo Y', fontsize=15)
ax.set_zlabel('Eixo Z', fontsize=15)

# Mostrar gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Criar figura e eixo 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Criar dados para plotagem da espiral
#dim_z = (data['Preço'].values)
#dim_x = (data['Trava'].values)
#dim_y = (data['Descoberto'].values)

# Plotar espiral de linha no plano 3D
#ax.scatter3D((data['Trava'].values),(data['Descoberto'].values) , (data['Preço'].values), c=(data['Preço'].values), cmap='Spectral')

# Configurar título e rótulos dos eixos
ax.set_title('Espiral de linha no Plano 3D', fontsize=18)
ax.set_xlabel('', fontsize=15)
ax.set_ylabel('Eixo Y', fontsize=15)
ax.set_zlabel('Preço', fontsize=15)

# Modificar ângulo de visualização do gráfico
ax.view_init(10, 25)

# Mostrar gráfico
plt.show()

# %%
vetor_serie = data['Série'].values
vetor_Preço = data['Preço'].values
vetor_coberto = data['Coberto'].values
vetor_trava = data['Trava'].values
vetor_descoberto = data['Descoberto'].values
plt.scatter( data['Preço'],data['Descoberto'],color = "r", s = 5 )
y = vetor_preco = data['Preço'].values
x = vetor_trava = data['Trava'].values

y2 = vetor_preco = data['Preço'].values
x2 = vetor_coberto = data['Coberto'].values



# Criar dados para plotagem da espiral
#dim_z = (data['Preço'].values)
#dim_x = (data['Trava'].values)
#dim_y = (data['Descoberto'].values)

# Plotar espiral de linha no plano 3D
#ax.scatter3D((data['Trava'].values),(data['Descoberto'].values) , (data['Preço'].values), c=(data['Preço'].values), cmap='Spectral')

# Configurar título e rótulos dos eixos
ax.set_title('Espiral de linha no Plano 3D', fontsize=18)
ax.set_xlabel('', fontsize=15)
ax.set_ylabel('Eixo Y', fontsize=15)
ax.set_zlabel('Preço', fontsize=15)

# Modificar ângulo de visualização do gráfico
ax.view_init(10, 25)

# Mostrar gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Criar figura e eixo 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

dim_z = (data['Preço'].values)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Criar figura e eixo 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D((data['Trava'].values),(data['Descoberto'].values) , (data['Preço'].values),c=(data['Preço'].values), cmap='Spectral')

# Criar dados para plotagem da espiral
dim_z = (data['Preço'].values)
dim_x = (data['Trava'].values)
dim_y = (data['Descoberto'].values)
ax.plot3D(dim_x, dim_y, dim_z, 'b')

ax.set_title('Espiral de linha e pontos no Plano 3D', fontsize=18)
ax.set_xlabel('Eixo X', fontsize=15)
ax.set_ylabel('Eixo Y', fontsize=15)
ax.set_zlabel('Preço', fontsize=15)

# [view_init] Modifica o ângulo de visualização do gráfico
ax.view_init(10, 35)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Criar figura e eixo 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotar os pontos com transparência
ax.scatter3D((data['Trava'].values),(data['Descoberto'].values) , (data['Preço'].values),c=(data['Preço'].values), cmap='Spectral', alpha=0.5)

# Plotar a linha espiral
dim_z = (data['Preço'].values)
dim_x = (data['Trava'].values)
dim_y = (data['Descoberto'].values)
ax.plot3D(dim_x, dim_y, dim_z, 'b')

ax.set_title('Espiral de linha e pontos no Plano 3D', fontsize=18)
ax.set_xlabel('Eixo X', fontsize=15)
ax.set_ylabel('Eixo Y', fontsize=15)
ax.set_zlabel('Preço', fontsize=15)

# [view_init] Modifica o ângulo de visualização do gráfico
ax.view_init(10, 35)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

vetor_serie = data['Série'].values
vetor_preco = data['Preço'].values
vetor_coberto = data['Coberto'].values
vetor_trava = data['Trava'].values
vetor_descoberto = data['Descoberto'].values

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter3D(vetor_trava, vetor_descoberto, vetor_preco, c=vetor_preco, cmap='Spectral')
ax.plot3D(vetor_trava, vetor_descoberto, vetor_preco, 'b')
#ax.bar3d(vetor_trava, vetor_descoberto, vetor_preco, c=vetor_preco, cmap='Spectral')
ax.set_xlabel('Trava (em milhares)', fontsize=15)
ax.set_ylabel('Descoberto (em milhares)', fontsize=15)
ax.set_zlabel('Preço', fontsize=15)
ax.set_title('Gráfico em 3D com preço, trava e descoberto', fontsize=18)

ax.view_init(10, 35)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(vetor_trava, vetor_descoberto, vetor_Preço, cmap='Spectral', edgecolor='none')
ax.set_xlabel('Trava')
ax.set_ylabel('Descoberto')
ax.set_zlabel('Preço')


ax.view_init(10, 35)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(vetor_trava, vetor_Preço, bins=10)
xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average', cmap='viridis')
ax.set_xlabel('Trava')
ax.set_ylabel('Preço')
ax.set_zlabel('Frequência')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vetor_trava /100, vetor_descoberto / 10000, vetor_Preço, c=vetor_Preço, cmap='Spectral')
ax.set_xlabel('Trava')
ax.set_ylabel('Descoberto')
ax.set_zlabel('Preço')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(vetor_trava, vetor_descoberto, vetor_Preço, cmap='plasma', edgecolor='none')
ax.set_xlabel('Trava')
ax.set_ylabel('Descoberto')
ax.set_zlabel('Preço')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Dados para o gráfico
vetor_serie = data['Série'].values
vetor_Preço = data['Preço'].values
vetor_coberto = data['Coberto'].values/10000
vetor_trava = data['Trava'].values/10000
vetor_descoberto = data['Descoberto'].values/10000

# Criar figura e eixo 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotar gráfico de dispersão
ax.scatter(vetor_trava, vetor_descoberto, vetor_Preço, c=vetor_Preço, cmap='magma')

# Configurar eixos e rótulos
ax.set_xlabel('Trava')
ax.set_ylabel('Descoberto')
ax.set_zlabel('Preço')

# Configurar visualização
ax.view_init(30, 30)

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.arange(-5, 5, 0.25)
y = np.arange(-5, 5, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)
ax.plot_surface(x, y, z)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()
